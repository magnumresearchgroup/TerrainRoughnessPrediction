# %% [markdown]
# # Model v13
#
# This model was trained and tested with images validated to contain a path (second round of validation).
#
# Roughness metric = 1 second ahead, k-means 3.

# %% [markdown]
# ## Set-up

# %%
# !pip install wandb

# %%
# !pip install "torch==1.4" "torchvision==0.5.0"
# Out:
# Collecting torch==1.4
#   Downloading https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 18kB/s
# Collecting torchvision==0.5.0
#   Downloading https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 52.6MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.19.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.15.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torch-1.4.0 torchvision-0.5.0

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls '/gdrive/My Drive/Labeling/Model/'
# Out:
# ImageFolder.ipynb  Images  Models.gdoc	Previous  v10  v11  v12  v13  v8  v9

# %%
from fastai.vision import *
import pandas as pd
import numpy as np
import os

# %%
import wandb
from wandb.fastai import WandbCallback

wandb.init(project='roughness-classifier-2')
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                 Tracking run with wandb version 0.10.12<br/>
#                 Syncing run <strong style="color:#cdcd00">toasty-darkness-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/gabrielag/roughness-classifier-2" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-2</a><br/>
#                 Run page: <a href="https://wandb.ai/gabrielag/roughness-classifier-2/runs/30yxlx36" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-2/runs/30yxlx36</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20201224_214026-30yxlx36</code><br/><br/>
# <h1>Run(30yxlx36)</h1><p></p><iframe src="https://wandb.ai/gabrielag/roughness-classifier-2/runs/30yxlx36" style="border:none;width:100%;height:400px"></iframe>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Model with `get_transforms(do_flip=False)`

# %% [markdown]
# #### Load data

# %%
path = '/gdrive/My Drive/Labeling/Model'
folder_path = os.path.join(path, 'v13')
image_path = os.path.join(path, 'Images')
label_path = '/gdrive/My Drive/Labeling/LabelsCSV/random_split/Metric2'

# %%
df = pd.read_csv(os.path.join(label_path, 'all_labels_path_metric_2_train.csv'))
df = df.filter(items=['image', 'group_3'])
df['group_3'] = df['group_3'].astype(int).astype(str)
df.head()
# Out:
#                  image group_3
# 0  969902383s228ms.jpg       0
# 1  969902516s227ms.jpg       0
# 2  969902832s243ms.jpg       0
# 3  970330409s202ms.jpg       1
# 4  969901887s232ms.jpg       1

# %%
print('All images:', len(os.listdir(image_path)))
print('Images in Path folder', len(os.listdir('/gdrive/My Drive/Labeling/PathDetectionClassifier/PredictImages/Path')))
print('Images in CSV (80% of Path folder):', len(df))
# Out:
# All images: 8983
# Images in Path folder 7070
# Images in CSV (80% of Path folder): 5647

# %% [markdown]
# #### Balance classes

# %%
group_0 = df[df['group_3'] == '0']
group_1 = df[df['group_3'] == '1']
group_2 = df[df['group_3'] == '2']

print(len(group_0))
print(len(group_1))
print(len(group_2))
# Out:
# 3101
# 1968
# 578

# %%
group_0 = group_0[:1200]
group_1 = group_1[:1200]

df_balanced = group_0.append(group_1).append(group_2)

print(len(df_balanced))
print(len(df_balanced[df_balanced['group_3'] == '0']))
print(len(df_balanced[df_balanced['group_3'] == '1']))
print(len(df_balanced[df_balanced['group_3'] == '2']))
# Out:
# 2978
# 1200
# 1200
# 578

# %% [markdown]
# #### DataBunch

# %% [markdown]
# The original image size is 3840 x 2160. We resize (squish) to a smaller image with the same aspect ratio (270 x 480, decreased by a factor of 8) [Link](https://fastai1.fast.ai/vision.transform.html#Data-augmentation-details).

# %%
bs = 64
# bs = 16    # uncomment this line if you run out of memory

# %%
np.random.seed(42)
data = (ImageList
        .from_df(path=image_path, df=df_balanced)
        .split_by_rand_pct(0.2)
        .label_from_df()
        .transform(get_transforms(do_flip=False), size=(270,480))
        .databunch(bs=bs)
        .normalize())

# %%
train_x = data.train_ds.x
train_y = data.train_ds.y
valid_x = data.valid_ds.x
valid_y = data.valid_ds.y

print(len(train_x), len(train_y))
print(len(valid_x), len(valid_y))
# Out:
# 2383 2383
# 595 595

# %%
print(data.classes)
# Out:
# ['0', '1', '2']

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# #### ResNet50

# %%
arch = models.resnet50
learn = cnn_learner(data, arch, metrics=[accuracy], callback_fns=WandbCallback)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 20:22<10:11]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.021021</td>
#       <td>#na#</td>
#       <td>12:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.901427</td>
#       <td>#na#</td>
#       <td>08:19</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       43.24% [16/37 03:35<04:42 6.4383]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 0.005

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.950794</td>
#       <td>1.628005</td>
#       <td>0.450420</td>
#       <td>11:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.450720</td>
#       <td>1.172225</td>
#       <td>0.517647</td>
#       <td>10:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.195175</td>
#       <td>0.995672</td>
#       <td>0.531092</td>
#       <td>10:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.052723</td>
#       <td>0.989727</td>
#       <td>0.532773</td>
#       <td>10:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.944696</td>
#       <td>0.965992</td>
#       <td>0.534454</td>
#       <td>10:16</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.628005027770996.
# Better model found at epoch 1 with valid_loss value: 1.1722251176834106.
# Better model found at epoch 2 with valid_loss value: 0.9956716299057007.
# Better model found at epoch 3 with valid_loss value: 0.9897271990776062.
# Better model found at epoch 4 with valid_loss value: 0.9659918546676636.
# Loaded best saved model from /content/wandb/run-20201224_214026-30yxlx36/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v13-stage-1'))

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
learn.load(os.path.join(folder_path, 'v13-stage-1'))

# %%
learn.fit_one_cycle(2, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.925589</td>
#       <td>1.129637</td>
#       <td>0.467227</td>
#       <td>10:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.947617</td>
#       <td>0.998853</td>
#       <td>0.531092</td>
#       <td>10:24</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.1296366453170776.
# Better model found at epoch 1 with valid_loss value: 0.9988529682159424.
# Loaded best saved model from /content/wandb/run-20201224_214026-30yxlx36/files/bestmodel.pth

# %% [markdown]
# #### Fine-tune

# %%
bs = 16    # uncomment this line if you run out of memory
learn.data.batch_size = 16

# %%
learn.data.batch_size
# Out:
# 16

# %%
learn.load(os.path.join(folder_path, 'v13-stage-1'))

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='148' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       57.43% [85/148 04:52<03:36 3.0493]
#     </div>
# Loaded best saved model from /content/wandb/run-20201224_214026-30yxlx36/files/bestmodel.pth
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.877410</td>
#       <td>0.961867</td>
#       <td>0.552941</td>
#       <td>10:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.873252</td>
#       <td>0.959940</td>
#       <td>0.541176</td>
#       <td>10:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.849108</td>
#       <td>0.964307</td>
#       <td>0.557983</td>
#       <td>10:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.817218</td>
#       <td>0.960909</td>
#       <td>0.544538</td>
#       <td>10:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.777241</td>
#       <td>0.962591</td>
#       <td>0.566387</td>
#       <td>10:20</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.961867094039917.
# Better model found at epoch 1 with valid_loss value: 0.9599395990371704.
# Loaded best saved model from /content/wandb/run-20201224_214026-30yxlx36/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v13-stage-2'))

# %%
learn.freeze()

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
 interp.plot_top_losses(9, figsize=(15,11))
