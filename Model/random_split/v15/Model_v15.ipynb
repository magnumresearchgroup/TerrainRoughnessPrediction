# %% [markdown]
# # Model v15
#
# This model was trained and tested with images validated to contain a path (second round of validation).
#
# Roughness metric = 1 second ahead, original groupings.

# %% [markdown]
# ## Set-up

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading https://files.pythonhosted.org/packages/ca/5e/9df94df3bfee51b92b54a5e6fa277d6e1fcdf1f27b1872214b98f55ec0f7/wandb-0.10.12-py2.py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 12.9MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from wandb) (3.13)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.12.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.1.2)
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Collecting watchdog>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/83/d9/3d1f46b428fd7b646725896b58d2eddb84f79fd76912773e6193cf74263d/watchdog-1.0.2-py3-none-manylinux2014_x86_64.whl (72kB)
#      |████████████████████████████████| 81kB 12.4MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/24/d1/a7f8fe3df258549b303415157328bfcc63e9b11d06a7ad7a3327f3d32606/GitPython-3.1.11-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 56.7MB/s
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/08/b2/ef713e0e67f6e7ec7d59aea3ee78d05b39c15930057e724cc6d362a8c3bb/configparser-5.0.1-py3-none-any.whl
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 13.6MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.3)
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/b1/5c/018bf9a5c24343a664deaea70e61f33f53bb1bd3caf193110f827bfd07e2/sentry_sdk-0.19.5-py2.py3-none-any.whl (128kB)
#      |████████████████████████████████| 133kB 52.8MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.12.0->wandb) (51.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.0.0->wandb) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 8.7MB/s
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Building wheels for collected packages: subprocess32
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6490 sha256=e933f1294e5481baee3736baa40eedc019782d8f70884a2934597052a8f516a9
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# Successfully built subprocess32
# Installing collected packages: shortuuid, watchdog, docker-pycreds, smmap, gitdb, GitPython, configparser, subprocess32, sentry-sdk, wandb
# Successfully installed GitPython-3.1.11 configparser-5.0.1 docker-pycreds-0.4.0 gitdb-4.0.5 sentry-sdk-0.19.5 shortuuid-1.0.1 smmap-3.0.4 subprocess32-3.5.4 wandb-0.10.12 watchdog-1.0.2

# %%
# !pip install "torch==1.4" "torchvision==0.5.0"
# Out:
# Collecting torch==1.4
#   Downloading https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 20kB/s
# Collecting torchvision==0.5.0
#   Downloading https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 56.1MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.19.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.15.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torch-1.4.0 torchvision-0.5.0

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls '/gdrive/My Drive/Labeling/Model/'
# Out:
# ImageFolder.ipynb  Models.gdoc	Results.gdoc  v11  v13	v15  v9
# Images		   Previous	v10	      v12  v14	v8

# %%
from fastai.vision import *
import pandas as pd
import numpy as np
import os

# %%
import wandb
from wandb.fastai import WandbCallback

wandb.init(project='roughness-classifier-2')
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                 Tracking run with wandb version 0.10.12<br/>
#                 Syncing run <strong style="color:#cdcd00">jumping-microwave-13</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/gabrielag/roughness-classifier-2" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-2</a><br/>
#                 Run page: <a href="https://wandb.ai/gabrielag/roughness-classifier-2/runs/3tr76zjj" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-2/runs/3tr76zjj</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20201227_160851-3tr76zjj</code><br/><br/>
# <h1>Run(3tr76zjj)</h1><p></p><iframe src="https://wandb.ai/gabrielag/roughness-classifier-2/runs/3tr76zjj" style="border:none;width:100%;height:400px"></iframe>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Model with `get_transforms(do_flip=False)`

# %% [markdown]
# #### Load data

# %%
path = '/gdrive/My Drive/Labeling/Model'
folder_path = os.path.join(path, 'v15')
image_path = os.path.join(path, 'Images')
label_path = '/gdrive/My Drive/Labeling/LabelsCSV/random_split/Metric2'

# %%
df = pd.read_csv(os.path.join(label_path, 'all_labels_path_metric_2_train.csv'))
df = df.filter(items=['image', 'group_original'])
df['group_original'] = df['group_original'].astype(int).astype(str)
df.head()
# Out:
#                  image group_original
# 0  969902383s228ms.jpg              1
# 1  969902516s227ms.jpg              1
# 2  969902832s243ms.jpg              1
# 3  970330409s202ms.jpg              1
# 4  969901887s232ms.jpg              2

# %%
print('All images:', len(os.listdir(image_path)))
print('Images in Path folder', len(os.listdir('/gdrive/My Drive/Labeling/PathDetectionClassifier/PredictImages/Path')))
print('Images in CSV (80% of Path folder):', len(df))
# Out:
# All images: 8983
# Images in Path folder 7070
# Images in CSV (80% of Path folder): 5647

# %% [markdown]
# #### Balance classes

# %%
group_0 = df[df['group_original'] == '0']
group_1 = df[df['group_original'] == '1']
group_2 = df[df['group_original'] == '2']
group_3 = df[df['group_original'] == '3']

print(len(group_0))
print(len(group_1))
print(len(group_2))
print(len(group_3))
# Out:
# 1100
# 2403
# 1223
# 921

# %%
group_1 = group_1[:1223]
group_2 = group_2[:1223]

df_balanced = group_0.append(group_1).append(group_2).append(group_3)

print(len(df_balanced))
print(len(df_balanced[df_balanced['group_original'] == '0']))
print(len(df_balanced[df_balanced['group_original'] == '1']))
print(len(df_balanced[df_balanced['group_original'] == '2']))
print(len(df_balanced[df_balanced['group_original'] == '3']))
# Out:
# 4467
# 1100
# 1223
# 1223
# 921

# %% [markdown]
# #### DataBunch

# %% [markdown]
# The original image size is 3840 x 2160. We resize (squish) to a smaller image with the same aspect ratio (270 x 480, decreased by a factor of 8) [Link](https://fastai1.fast.ai/vision.transform.html#Data-augmentation-details).

# %%
bs = 64
# bs = 16    # uncomment this line if you run out of memory

# %%
np.random.seed(42)
data = (ImageList
        .from_df(path=image_path, df=df_balanced)
        .split_by_rand_pct(0.2)
        .label_from_df()
        .transform(get_transforms(do_flip=False), size=(270,480))
        .databunch(bs=bs)
        .normalize())

# %%
train_x = data.train_ds.x
train_y = data.train_ds.y
valid_x = data.valid_ds.x
valid_y = data.valid_ds.y

print(len(train_x), len(train_y))
print(len(valid_x), len(valid_y))
# Out:
# 3574 3574
# 893 893

# %%
print(data.classes)
# Out:
# ['0', '1', '2', '3']

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# #### ResNet50

# %%
arch = models.resnet50
learn = cnn_learner(data, arch, metrics=[accuracy], callback_fns=WandbCallback)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 17:19<17:19]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.331406</td>
#       <td>#na#</td>
#       <td>17:19</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='35' class='' max='55' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       63.64% [35/55 08:14<04:42 7.8331]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 0.001

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.135311</td>
#       <td>1.622072</td>
#       <td>0.393057</td>
#       <td>17:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.973809</td>
#       <td>1.502101</td>
#       <td>0.389698</td>
#       <td>19:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.707104</td>
#       <td>1.326614</td>
#       <td>0.409854</td>
#       <td>19:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.501309</td>
#       <td>1.276985</td>
#       <td>0.418813</td>
#       <td>19:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.381196</td>
#       <td>1.264831</td>
#       <td>0.421053</td>
#       <td>19:12</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.6220722198486328.
# Better model found at epoch 1 with valid_loss value: 1.5021010637283325.
# Better model found at epoch 2 with valid_loss value: 1.3266139030456543.
# Better model found at epoch 3 with valid_loss value: 1.2769850492477417.
# Better model found at epoch 4 with valid_loss value: 1.2648309469223022.
# Loaded best saved model from /content/wandb/run-20201226_200843-3pxsqegv/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v15-stage-1'))

# %%
learn.fit_one_cycle(2, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.394580</td>
#       <td>1.317611</td>
#       <td>0.434490</td>
#       <td>19:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.325802</td>
#       <td>1.227040</td>
#       <td>0.431131</td>
#       <td>18:57</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.317610502243042.
# Better model found at epoch 1 with valid_loss value: 1.2270396947860718.
# Loaded best saved model from /content/wandb/run-20201226_200843-3pxsqegv/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v15-stage-1'))

# %%
learn.load(os.path.join(folder_path, 'v15-stage-1'))

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# #### Fine-tune

# %%
bs = 16    # uncomment this line if you run out of memory
learn.data.batch_size = 16

# %%
learn.data.batch_size
# Out:
# 16

# %%
learn.load(os.path.join(folder_path, 'v15-stage-1'))

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='223' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       38.12% [85/223 05:59<09:43 3.4035]
#     </div>
# Loaded best saved model from /content/wandb/run-20201227_160851-3tr76zjj/files/bestmodel.pth
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.329067</td>
#       <td>1.213265</td>
#       <td>0.449048</td>
#       <td>20:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.307874</td>
#       <td>1.210953</td>
#       <td>0.430011</td>
#       <td>20:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.276750</td>
#       <td>1.196983</td>
#       <td>0.445689</td>
#       <td>20:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.179511</td>
#       <td>1.203581</td>
#       <td>0.440090</td>
#       <td>20:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.192389</td>
#       <td>1.199153</td>
#       <td>0.450168</td>
#       <td>20:21</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.2132645845413208.
# Better model found at epoch 1 with valid_loss value: 1.2109533548355103.
# Better model found at epoch 2 with valid_loss value: 1.1969832181930542.
# Loaded best saved model from /content/wandb/run-20201227_160851-3tr76zjj/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v15-stage-2'))

# %%
learn.fit_one_cycle(2, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.202518</td>
#       <td>1.212833</td>
#       <td>0.455767</td>
#       <td>20:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.211707</td>
#       <td>1.193130</td>
#       <td>0.462486</td>
#       <td>20:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.2128328084945679.
# Better model found at epoch 1 with valid_loss value: 1.1931297779083252.
# Loaded best saved model from /content/wandb/run-20201227_160851-3tr76zjj/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v15-stage-2'))

# %%
learn.fit_one_cycle(2, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.164750</td>
#       <td>1.217126</td>
#       <td>0.450168</td>
#       <td>20:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.130392</td>
#       <td>1.205588</td>
#       <td>0.449048</td>
#       <td>20:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.2171261310577393.
# Better model found at epoch 1 with valid_loss value: 1.2055882215499878.
# Loaded best saved model from /content/wandb/run-20201227_160851-3tr76zjj/files/bestmodel.pth

# %%
learn.load(os.path.join(folder_path, 'v15-stage-2'))

# %%
learn.freeze()

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
 interp.plot_top_losses(9, figsize=(15,11))
