# %% [markdown]
# # Model v10
#
# This model was trained and tested with images validated to contain a path (second round of validation).
#
# Roughness metric = k-means 4.

# %% [markdown]
# ## Set-up

# %%
# !pip install wandb

# %%
# !pip install "torch==1.4" "torchvision==0.5.0"
# Out:
# Collecting torch==1.4
#   Downloading https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 21kB/s
# Collecting torchvision==0.5.0
#   Downloading https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 50.7MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.19.4)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torch-1.4.0 torchvision-0.5.0

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls '/gdrive/My Drive/Labeling/Model/'
# Out:
# ImageFolder.ipynb  Images  Models.gdoc	Previous  v8  v9

# %%
from fastai.vision import *
import pandas as pd
import numpy as np
import os

# %%
import wandb
from wandb.fastai import WandbCallback

wandb.init(project='roughness-classifier-2')
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                 Tracking run with wandb version 0.10.12<br/>
#                 Syncing run <strong style="color:#cdcd00">cerulean-leaf-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/gabrielag/roughness-classifier-2" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-2</a><br/>
#                 Run page: <a href="https://wandb.ai/gabrielag/roughness-classifier-2/runs/2auzpxav" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-2/runs/2auzpxav</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20201221_220420-2auzpxav</code><br/><br/>
# <h1>Run(2auzpxav)</h1><p></p><iframe src="https://wandb.ai/gabrielag/roughness-classifier-2/runs/2auzpxav" style="border:none;width:100%;height:400px"></iframe>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Model with `get_transforms(do_flip=False)`

# %% [markdown]
# #### Load data

# %%
path = '/gdrive/My Drive/Labeling/Model'
df = pd.read_csv('/gdrive/My Drive/Labeling/LabelsCSV/random_split/Metric1/all_labels_path_train.csv')
df = df.filter(items=['image', 'group_4'])
df['group_4'] = df['group_4'].astype(int).astype(str)
df.head()
# Out:
#                  image group_4
# 0  969902383s228ms.jpg       2
# 1  969902516s227ms.jpg       1
# 2  969902832s243ms.jpg       0
# 3  970330409s202ms.jpg       0
# 4  969901887s232ms.jpg       0

# %%
image_path = os.path.join(path, 'Images')

print('All images:', len(os.listdir(image_path)))
print('Images in Labeling/PathDetectionClassifier/PredictImages/Path:', len(os.listdir('/gdrive/My Drive/Labeling/PathDetectionClassifier/PredictImages/Path')))
print('Images with labels in CSV (should be 80% of the images in the Path folder):', len(df))
# Out:
# All images: 8983
# Images in Labeling/PathDetectionClassifier/PredictImages/Path: 7070
# Images with labels in CSV (should be 80% of the images in the Path folder): 5656

# %% [markdown]
# #### Balance classes

# %%
group_0 = df[df['group_4'] == '0']
group_1 = df[df['group_4'] == '1']
group_2 = df[df['group_4'] == '2']
group_3 = df[df['group_4'] == '3']

print(len(group_0))
print(len(group_1))
print(len(group_2))
print(len(group_3))
# Out:
# 2227
# 2101
# 1012
# 316

# %%
group_0 = group_0[:1012]
group_1 = group_1[:1012]
group_2 = group_2[:1012]

df_balanced = group_0.append(group_1).append(group_2).append(group_3)

print(len(df_balanced))

print(len(df_balanced[df_balanced['group_4'] == '0']))
print(len(df_balanced[df_balanced['group_4'] == '1']))
print(len(df_balanced[df_balanced['group_4'] == '2']))
print(len(df_balanced[df_balanced['group_4'] == '3']))
# Out:
# 3352
# 1012
# 1012
# 1012
# 316

# %% [markdown]
# #### DataBunch

# %% [markdown]
# The original image size is 3840 x 2160. We resize (squish) to a smaller image with the same aspect ratio (270 x 480, decreased by a factor of 8) [Link](https://fastai1.fast.ai/vision.transform.html#Data-augmentation-details).

# %%
bs = 64
# bs = 16    # uncomment this line if you run out of memory

# %%
np.random.seed(42)
data = (ImageList
        .from_df(path=image_path, df=df_balanced)
        .split_by_rand_pct(0.2)
        .label_from_df()
        .transform(get_transforms(do_flip=False), size=(270,480))
        .databunch()
        .normalize())

# %%
train_x = data.train_ds.x
train_y = data.train_ds.y
valid_x = data.valid_ds.x
valid_y = data.valid_ds.y

print(len(train_x), len(train_y))
print(len(valid_x), len(valid_y))
# Out:
# 2682 2682
# 670 670

# %%
print(data.classes)
# Out:
# ['0', '1', '2', '3']

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# #### ResNet50

# %%
arch = models.resnet50
learn = cnn_learner(data, arch, metrics=[accuracy], callback_fns=WandbCallback)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 22:34<11:17]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.422184</td>
#       <td>#na#</td>
#       <td>13:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.837166</td>
#       <td>#na#</td>
#       <td>09:19</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='41' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       19.51% [8/41 01:48<07:29 8.3934]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 0.001

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.313531</td>
#       <td>1.775228</td>
#       <td>0.334328</td>
#       <td>12:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.192252</td>
#       <td>1.732309</td>
#       <td>0.388060</td>
#       <td>11:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.880393</td>
#       <td>1.435446</td>
#       <td>0.394030</td>
#       <td>11:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.651575</td>
#       <td>1.366192</td>
#       <td>0.397015</td>
#       <td>11:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.499642</td>
#       <td>1.341401</td>
#       <td>0.402985</td>
#       <td>11:44</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.7752281427383423.
# Better model found at epoch 1 with valid_loss value: 1.7323087453842163.
# Better model found at epoch 2 with valid_loss value: 1.4354459047317505.
# Better model found at epoch 3 with valid_loss value: 1.366192102432251.
# Better model found at epoch 4 with valid_loss value: 1.3414007425308228.
# Loaded best saved model from /content/wandb/run-20201221_220420-2auzpxav/files/bestmodel.pth

# %%
learn.save(os.path.join(path, 'v10/v10-stage-1-rn50'))

# %%
learn.fit_one_cycle(1, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.389799</td>
#       <td>1.398273</td>
#       <td>0.383582</td>
#       <td>12:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.3982725143432617.
# Loaded best saved model from /content/wandb/run-20201221_220420-2auzpxav/files/bestmodel.pth

# %%
learn.load(os.path.join(path, 'v10/v10-stage-1-rn50'))

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# #### Fine-tune

# %%
# bs = 64
bs = 16    # uncomment this line if you run out of memory
learn.data.batch_size = bs

# %%
learn.data.batch_size
# Out:
# 16

# %%
learn.load(os.path.join(path, 'v10/v10-stage-1-rn50'))

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='167' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.90% [85/167 05:08<04:57 4.4975]
#     </div>
# Loaded best saved model from /content/wandb/run-20201221_220420-2auzpxav/files/bestmodel.pth
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.507231</td>
#       <td>1.348448</td>
#       <td>0.383582</td>
#       <td>13:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.475137</td>
#       <td>1.344400</td>
#       <td>0.398507</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.397676</td>
#       <td>1.384532</td>
#       <td>0.394030</td>
#       <td>12:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.387637</td>
#       <td>1.349442</td>
#       <td>0.401493</td>
#       <td>12:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.325410</td>
#       <td>1.320935</td>
#       <td>0.408955</td>
#       <td>12:26</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.3484479188919067.
# Better model found at epoch 1 with valid_loss value: 1.3444002866744995.
# Better model found at epoch 4 with valid_loss value: 1.3209353685379028.
# Loaded best saved model from /content/wandb/run-20201221_220420-2auzpxav/files/bestmodel.pth

# %%
learn.save(os.path.join(path, 'v10/v10-stage-2-rn50'))

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
learn.fit_one_cycle(1, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.339132</td>
#       <td>1.312047</td>
#       <td>0.426866</td>
#       <td>13:46</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.3120468854904175.
# Loaded best saved model from /content/wandb/run-20201221_220420-2auzpxav/files/bestmodel.pth

# %%
learn.save(os.path.join(path, 'v10/v10-stage-2-rn50'))

# %%
learn.fit_one_cycle(1, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.322445</td>
#       <td>1.337204</td>
#       <td>0.405970</td>
#       <td>14:20</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.3372044563293457.
# Loaded best saved model from /content/wandb/run-20201221_220420-2auzpxav/files/bestmodel.pth

# %%
learn.load(os.path.join(path, 'v10/v10-stage-2-rn50'))

# %%
learn.freeze()

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
 interp.plot_top_losses(9, figsize=(15,11))
