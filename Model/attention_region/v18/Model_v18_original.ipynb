# %% [markdown]
# # Model v18_original
#
# This model is a baseline for evaluating v18_attention. It is the same model, except the images do not have the attention region.
#
# Path images, roughness metric = 1 second ahead, k-means 2, data split within sessions, the same images are used as v18 except these images do not have the attention region.

# %% [markdown]
# ## Set-up

# %%
# !pip install wandb

# %%
# !pip install "torch==1.4" "torchvision==0.5.0"
# Out:
# Collecting torch==1.4
#   Downloading https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 21kB/s
# Collecting torchvision==0.5.0
#   Downloading https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 41.6MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.19.4)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torch-1.4.0 torchvision-0.5.0

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from fastai.vision import *
import pandas as pd
import numpy as np
import os

# %%
import wandb
from wandb.fastai import WandbCallback

wandb.init(project='roughness-classifier-4')
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                 Tracking run with wandb version 0.10.12<br/>
#                 Syncing run <strong style="color:#cdcd00">sparkling-resonance-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/gabrielag/roughness-classifier-4" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-4</a><br/>
#                 Run page: <a href="https://wandb.ai/gabrielag/roughness-classifier-4/runs/13jp6rll" target="_blank">https://wandb.ai/gabrielag/roughness-classifier-4/runs/13jp6rll</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210107_171448-13jp6rll</code><br/><br/>
# <h1>Run(13jp6rll)</h1><p></p><iframe src="https://wandb.ai/gabrielag/roughness-classifier-4/runs/13jp6rll" style="border:none;width:100%;height:400px"></iframe>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Model

# %% [markdown]
# #### Load data

# %%
path = '/gdrive/My Drive/Labeling/Model'
folder_path = os.path.join(path, 'attention_region', 'v18')
image_path = os.path.join(path, 'Images')
label_path = '/gdrive/My Drive/Labeling/LabelsCSV'

# %%
df = pd.read_csv(os.path.join(label_path, 'attention_region', 'labels_path_validated_mask_split_metric_2.csv'))
df = df.filter(items=['image', 'group_2', 'dataset'])

# Categorical data
df['group_2'] = df['group_2'].astype(int).astype(str)

# Create is_valid column
df['is_valid'] = df['dataset'] == 'valid'

# Training set, filter out dataset column
train = df[df['dataset'] == 'train'].filter(items=['image', 'group_2', 'is_valid'])

# Validation set, filter out dataset column
valid = df[df['dataset'] == 'valid'].filter(items=['image', 'group_2', 'is_valid'])

# %% [markdown]
# #### Balance classes

# %%
# Training set
group_0 = train[train['group_2'] == '0']
group_1 = train[train['group_2'] == '1']

print(len(group_0))
print(len(group_1))
# Out:
# 2838
# 751

# %%
group_0 = group_0[:827]

train_balanced = group_0.append(group_1)

print(len(train_balanced))
print(len(train_balanced[train_balanced['group_2'] == '0']))
print(len(train_balanced[train_balanced['group_2'] == '1']))
# Out:
# 1578
# 827
# 751

# %%
# Validation set
group_0_v = valid[valid['group_2'] == '0']
group_1_v = valid[valid['group_2'] == '1']

print(len(group_0_v))
print(len(group_1_v))
# Out:
# 676
# 224

# %%
group_0_v = group_0_v[:246]

valid_balanced = group_0_v.append(group_1_v)
print(len(valid_balanced))
print(len(valid_balanced[valid_balanced['group_2'] == '0']))
print(len(valid_balanced[valid_balanced['group_2'] == '1']))
# Out:
# 470
# 246
# 224

# %%
df_balanced = train_balanced.append(valid_balanced)
print(len(df_balanced))
print(len(df_balanced[df_balanced['is_valid'] == False]))
print(len(df_balanced[df_balanced['is_valid'] == True]))
# Out:
# 2048
# 1578
# 470

# %%
df_balanced.head()
# Out:
#                  image group_2  is_valid
# 0  969905035s184ms.jpg       0     False
# 1  970588340s260ms.jpg       0     False
# 2  969905551s166ms.jpg       0     False
# 3  970588244s264ms.jpg       0     False
# 4  970328566s709ms.jpg       0     False

# %% [markdown]
# #### DataBunch

# %% [markdown]
# The original image size is 3840 x 2160. We resize (squish) to a smaller image with the same aspect ratio (270 x 480, decreased by a factor of 8) [Link](https://fastai1.fast.ai/vision.transform.html#Data-augmentation-details).

# %%
bs = 64

# %%
np.random.seed(42)
data = (ImageList
        .from_df(path=image_path, df=df_balanced)
        .split_from_df(col='is_valid')
        .label_from_df(cols='group_2')
        .transform(get_transforms(do_flip=False), size=(270,480))
        .databunch(bs=bs)
        .normalize())

# %%
train_x = data.train_ds.x
train_y = data.train_ds.y
valid_x = data.valid_ds.x
valid_y = data.valid_ds.y

print(len(train_x), len(train_y))
print(len(valid_x), len(valid_y))
# Out:
# 1578 1578
# 470 470

# %%
print(data.classes)
# Out:
# ['0', '1']

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# #### ResNet50

# %%
arch = models.resnet50
learn = cnn_learner(data, arch, metrics=[accuracy], callback_fns=WandbCallback)
# learn = cnn_learner(data, arch, metrics=[accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 25:29<16:59]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.197787</td>
#       <td>#na#</td>
#       <td>14:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.209900</td>
#       <td>#na#</td>
#       <td>05:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.212419</td>
#       <td>#na#</td>
#       <td>05:20</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='24' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.83% [17/24 03:53<01:36 3.5123]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 0.01

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.309462</td>
#       <td>1.355963</td>
#       <td>0.634043</td>
#       <td>10:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.000468</td>
#       <td>1.181764</td>
#       <td>0.540426</td>
#       <td>06:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.837102</td>
#       <td>0.798608</td>
#       <td>0.651064</td>
#       <td>06:54</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.724116</td>
#       <td>0.677033</td>
#       <td>0.687234</td>
#       <td>06:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.653937</td>
#       <td>0.692811</td>
#       <td>0.680851</td>
#       <td>06:57</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.3559633493423462.
# Better model found at epoch 1 with valid_loss value: 1.181764006614685.
# Better model found at epoch 2 with valid_loss value: 0.7986076474189758.
# Better model found at epoch 3 with valid_loss value: 0.6770333647727966.
# Loaded best saved model from /content/wandb/run-20210107_171448-13jp6rll/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v18-original-stage-1'))

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# #### Fine-tune

# %%
learn.load(os.path.join(folder_path, 'v18-original-stage-1'))

# %%
learn.data.batch_size = 16

# %%
learn.data.batch_size
# Out:
# 16

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='98' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.69% [83/98 04:42<00:50 1.5782]
#     </div>
# Loaded best saved model from /content/wandb/run-20210107_171448-13jp6rll/files/bestmodel.pth
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.559526</td>
#       <td>0.675916</td>
#       <td>0.697872</td>
#       <td>07:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.559292</td>
#       <td>0.734269</td>
#       <td>0.657447</td>
#       <td>07:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.543422</td>
#       <td>0.668608</td>
#       <td>0.702128</td>
#       <td>07:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.506584</td>
#       <td>0.672096</td>
#       <td>0.685106</td>
#       <td>07:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.483501</td>
#       <td>0.699781</td>
#       <td>0.680851</td>
#       <td>07:03</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.6759157180786133.
# Better model found at epoch 2 with valid_loss value: 0.6686076521873474.
# Loaded best saved model from /content/wandb/run-20210107_171448-13jp6rll/files/bestmodel.pth

# %%
learn.save(os.path.join(folder_path, 'v18-original-stage-2'))

# %%
learn.freeze()

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,11))
