# %% [markdown]
# # Valid Images
# Create a DataFrame for each session with the valid images.
#
# **Validation:**
# Each image considers the readings closest to and after the image timestamp up until 1 second ahead. For simplicity, we simplify the ranges in terms of seconds as follows:
# - The reading closest to and after `image_s, image_ms` will always have a seconds reading of `image_s` or `image_s + 1`. For example (1000, 999) may be closest to (1001, 2). If the closest reading falls outside of this range, it is not valid.
# - The calculation of the roughness metric considers readings 1 second ahead of the closest to and after roughness reading. Consider the example above, where the closest reading was (1001, 2). In this case, readings will be considered up until (1002, 2). Since we just want to deal with seconds, we will check to make sure that there is data up to `image_s + 3`.
#
# 1. The image name must be in the format `[0-9]*s[0-9]*ms`.
#
# 2. `withinRange` to confirms that `image_s` is after `rec_df` and `rough_df` begin and `image_s + 3` is before `rec_df` and `rough_df` end.
#
# 3. `nonzero` checks that `rec_df` from `image_s` to `image_s + 3` have nonzero speeds.
#
# 4. `continuous` checks that:
#   - Readings in `rec_df` from `image_s` to `image_s + 3` should be no more than 1 second apart.
#   - Readings in `rough_df` from `image_s` to `image_s + 3` should be no more than 50 ms apart (most readings are ~ 10 ms apart).

# %% [markdown]
# ## Set-up

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
from collections import namedtuple
import csv
import re

# %% [markdown]
# ## Helper functions

# %%
# Difference in ms between t1 and t2
# Negative if s1 is before s2, positive if s2 is before s1
def findDifferenceMs(s1, ms1, s2, ms2):
  if (s1 > s2):
    return (s1-s2-1)*1000 + (1000-ms2) + ms1
  elif (s1 < s2):
    return -((s2-s1-1)*1000 + (1000-ms1) + ms2)
  else:
    return ms1-ms2

# Parse s and ms from image name in format XsYms
def parse_times(name):
  lhs, rhs = name.split("s", 1)
  rhs, ignore = rhs.split("ms", 1);
  return int(lhs), int(rhs)

# %% [markdown]
# ## Criteria for a valid image

# %% [markdown]
# #### Helper functions

# %%
# Return an empty DataFrame if there was a validation issue, else return
# the window of rec_df corresponding to the values used in labeling the image.
def rec_df_window(s, ms, rec_df):
  window = rec_df[rec_df['utc_s (s)'] >= s]
  window = window[window['utc_s (s)'] <= s + 3]

  # If there are not readings at s, s + 1, s + 2, and s + 3, validation error.
  if len(window) != 4:
    return pd.DataFrame()
  
  return window

# %%
def rough_df_window(s, ms, rough_df):
  window = rough_df[rough_df['utc_s'] >= s]
  window = window[window['utc_s'] <= s + 3]
  return window

# %% [markdown]
# #### Validity checks

# %%
# (df_s1, df_ms1) is the start time of df, (df_s2, df_ms2) is the end time of df
def withinRange(s, ms, df_s1, df_ms1, df_s2, df_ms2):
  if findDifferenceMs(s, 0, df_s1, df_ms1) < 0:
    return False
  
  if findDifferenceMs(df_s2, df_ms2, s + 3, 0) < 0:
    return False

  return True

# %%
def nonzero(rec_window):
  for _, row in rec_window.iterrows():
    if row['enhanced_speed (m/s)'] == 0:
      return False
  
  return True

# %%
def continuous(df, tolerance, utc_s, utc_ms):
  for i in range(len(df)):
    if i == 0:
      continue
      
    if findDifferenceMs(df[utc_s].iloc[i], df[utc_ms].iloc[i], df[utc_s].iloc[i-1], df[utc_ms].iloc[i-1]) > tolerance:
      return False
  
  return True

# %%
def is_valid(image, rec_df, rough_df):
  s, ms = parse_times(image)

  # Criteria 1: Image name is in format XsYms
  if not bool(re.match("[0-9]*s[0-9]*ms", image)):
    print("Image", image, "has an improper name format.")
    return False
  
  # Criteria 2: Image time - int(1 + (window / 1000.)) should be after df_s, df_ms
  in_range_rec = withinRange(s, ms, rec_df['utc_s (s)'].iloc[0], rec_df['utc_ms (ms)'].iloc[0], rec_df['utc_s (s)'].iloc[-1], rec_df['utc_ms (ms)'].iloc[-1])
  in_range_rough = withinRange(s, ms, rough_df['utc_s'].iloc[0], rough_df['utc_ms'].iloc[0], rough_df['utc_s'].iloc[-1], rough_df['utc_ms'].iloc[-1])
  if not in_range_rec or not in_range_rough:
    print("Image", image, "is not in range.")
    return False

  # Criteria 3: Additional range checks during creation of rec_window
  # If one of these check fails, rec_window = pd.DataFrame()
  rec_window = rec_df_window(s, ms, rec_df)
  if len(rec_window) == 0:
    print("Image", image, "had validation errors in rec_df_window.")
    return False
  
  # Criteria 4: The speeds in the window surrounding the image must be nonzero
  if not nonzero(rec_window):
    print("Image", image, "has one or more speed readings = 0.")
    return False
  
  # Criteria 5: Timestamps in record.csv, roughness_metric.csv, and gps.csv are continuous
  rough_window = rough_df_window(s, ms, rough_df)
  
  continuous_rec = continuous(rec_window, 1001, 'utc_s (s)', 'utc_ms (ms)')
  continuous_rough = continuous(rough_window, 50, 'utc_s', 'utc_ms')
  
  if not (continuous_rec and continuous_rough):    
    print("Image", image, "does not have continuous readings.")
    return False

  return True

# %% [markdown]
# ## Test data

# %%
# test_rec_df = pd.read_csv('/gdrive/My Drive/Labeling/SensorData/Garmin/2020-09-29-09-46-42-garmin/record.csv', index_col=0)
# test_rec_df = test_rec_df.filter(items=['utc_s (s)', 'utc_ms (ms)', 'distance (m)', 'enhanced_speed (m/s)'])
# test_rough_df = pd.read_csv('/gdrive/My Drive/Labeling/SensorData/Virb/2020-09-29-09-46-42/roughness_metric.csv', index_col=0)

# # Test nonzero
# # Range with 0 values: 2771 - 2820, 970328033 - 970328081
# # Range with no 0 values: 100 - 120, 970325361 - 970325380, however not in range with gps.csv
# # Range where second part has 0 values: 2746 - 2747, 970328008 - 970328009 
# # Range where first part has 0 values: 2868 - 2869, 970328130 - 970328131
# print('\n', is_valid("970328034s0ms", test_rec_df, test_rough_df))
# print('\n', is_valid("970325361s50ms", test_rec_df, test_rough_df))
# print('\n', is_valid("970328008s50ms", test_rec_df, test_rough_df))
# print('\n', is_valid("970328130s50ms", test_rec_df, test_rough_df))

# # Test withinRange
# # Start time of test_rec_df = (970325257, 0)
# # Start time of test_rough_df = (970325257, 571)
# print('\n', is_valid("970325257s0ms", test_rec_df, test_rough_df))
# print('\n', is_valid("970325258s0ms", test_rec_df, test_rough_df))
# print('\n', is_valid("970325258s571ms", test_rec_df, test_rough_df))
# print('\n', is_valid("970325500s0ms", test_rec_df, test_rough_df))

# # Test consistent_utc
# print('\n', is_valid("970327043s0ms", test_rec_df, test_rough_df))
# print('\n', is_valid("970329000s0ms", test_rec_df, test_rough_df))
# Out:
#       utc_s (s)  utc_ms (ms)  distance (m)  enhanced_speed (m/s)
# 2772  970328034            0       9522.26                   0.0
# 2773  970328035            0       9522.26                   0.0
# 2774  970328036            0       9522.26                   0.0
# 2775  970328037            0       9522.26                   0.0
# Image 970328034s0ms has one or more speed readings = 0.
#
#  False
#      utc_s (s)  utc_ms (ms)  distance (m)  enhanced_speed (m/s)
# 100  970325361            0        253.85                 2.519
# 101  970325362            0        256.49                 2.641
# 102  970325363            0        258.92                 2.435
# 103  970325364            0        261.63                 2.706
#
#  True
#       utc_s (s)  utc_ms (ms)  distance (m)  enhanced_speed (m/s)
# 2746  970328008            0       9522.26                 2.967
# 2747  970328009            0       9522.26                 0.000
# 2748  970328010            0       9522.26                 0.000
# 2749  970328011            0       9522.26                 0.000
# Image 970328008s50ms has one or more speed readings = 0.
#
#  False
#       utc_s (s)  utc_ms (ms)  distance (m)  enhanced_speed (m/s)
# 2868  970328130            0       9522.26                 0.000
# 2869  970328131            0       9522.34                 0.075
# 2870  970328132            0       9525.83                 3.499
# 2871  970328133            0       9529.56                 3.732
# Image 970328130s50ms has one or more speed readings = 0.
#
#  False
# Image 970325257s0ms is not in range.
#
#  False
# Empty DataFrame
# Columns: [utc_s (s), utc_ms (ms), distance (m), enhanced_speed (m/s)]
# Index: []
# Image 970325258s0ms had validation errors in rec_df_window.
#
#  False
# Empty DataFrame
# Columns: [utc_s (s), utc_ms (ms), distance (m), enhanced_speed (m/s)]
# Index: []
# Image 970325258s571ms had validation errors in rec_df_window.
#
#  False
#      utc_s (s)  utc_ms (ms)  distance (m)  enhanced_speed (m/s)
# 238  970325500            0        704.57                 2.771
# 239  970325501            0        707.28                 2.706
# 240  970325502            0        709.71                 2.426
# 241  970325503            0        712.25                 2.547
#
#  True
#       utc_s (s)  utc_ms (ms)  distance (m)  enhanced_speed (m/s)
# 1781  970327043            0       6142.56                 2.790
# 1782  970327044            0       6145.89                 3.322
# 1783  970327045            0       6149.73                 3.844
# 1784  970327046            0       6152.96                 3.228
#
#  True
#       utc_s (s)  utc_ms (ms)  distance (m)  enhanced_speed (m/s)
# 3738  970329000            0      12428.83                 1.922
# 3739  970329001            0      12430.93                 2.099
# 3740  970329002            0      12432.82                 1.885
# 3741  970329003            0      12434.74                 1.922
#
#  True

# %% [markdown]
# ## Create DataFrame with valid images

# %%
CSVDirs = namedtuple('CSVDirs', ['virb_dir', 'garmin_dir'])

def csv_path(folder):
  root_csv_dir = '/gdrive/My Drive/Labeling/SensorData'
  virb_dir = os.path.join(root_csv_dir, 'Virb', folder)
  garmin_dir = os.path.join(root_csv_dir, 'Garmin', folder + '-garmin')
  return CSVDirs(virb_dir, garmin_dir)

video_csvs = {
    "2020-07-28-06-01-11": csv_path('2020-07-28-06-01-11'),
    "2020-09-23-VIRB0001": csv_path('2020-09-23-16-10-10'),
    "2020-09-23-VIRB0002": csv_path('2020-09-23-16-10-10'),
    "2020-09-23-VIRB0004": csv_path('2020-09-23-16-10-10'),
    "2020-09-23-VIRB0008": csv_path('2020-09-23-16-10-10'),
    "2020-09-24-1": csv_path('2020-09-24-12-07-41'),
    "2020-09-24-2": csv_path('2020-09-24-12-07-41'),
    "2020-09-24-3": csv_path('2020-09-24-12-07-41'),
    "2020-09-24-4": csv_path('2020-09-24-12-07-41'),
    "2020-09-29-09-46-42-1": csv_path('2020-09-29-09-46-42'),
    "2020-09-29-09-46-42-2": csv_path('2020-09-29-09-46-42'),
    "2020-09-29-09-46-42-3": csv_path('2020-09-29-09-46-42'),
    "2020-09-29-09-46-42-4": csv_path('2020-09-29-09-46-42'),
    "2020-10-02-10-17-05-1": csv_path('2020-10-02-10-17-05'),
    "2020-10-02-10-17-05-2": csv_path('2020-10-02-10-17-05'),
    "2020-10-02-10-17-05-3": csv_path('2020-10-02-10-17-05'),
}

# %%
# Label all images in Labeling/VideoData/RealVideoSplit/VideoFrames
def valid_images():
  with open('/gdrive/My Drive/Labeling/ValidImages/Metric_2/valid_images.txt', 'w') as outfile:
    
    frame_directory = '/gdrive/My Drive/Labeling/VideoData/RealVideoSplit/VideoFrames'
    for root, dirs, files in os.walk(frame_directory):
      if root == '/gdrive/My Drive/Labeling/VideoData/RealVideoSplit/VideoFrames':
        for dir in dirs:
          if dir in video_csvs:
            virb_dir = video_csvs[dir].virb_dir
            garmin_dir = video_csvs[dir].garmin_dir
            df = valid_images_in_folder(os.path.join(root, dir), virb_dir, garmin_dir)
            output = dir + "\nNumber of valid images: " + str(len(df)) + " Total images: " + str(len(os.listdir(os.path.join(root,dir)))) + "\n"
            outfile.write(output)

            csv_name = dir + '.csv'
            df.to_csv(os.path.join('/gdrive/My Drive/Labeling/ValidImages/Metric_2', csv_name), index=False)

# %%
# Return lists with the video name, image name, and roughness group for all 
# images in the folder
def valid_images_in_folder(folder_dir, virb_dir, garmin_dir):
  folder = os.path.split(folder_dir)[1]
  print("Creating list of valid images in folder", folder)

  valid_images = pd.DataFrame()
  image_list = []

  rec_df = pd.read_csv(os.path.join(garmin_dir, "record.csv"), index_col=0)
  rec_df = rec_df.filter(items=['utc_s (s)', 'utc_ms (ms)', 'distance (m)', 'enhanced_speed (m/s)'])
  rough_df = pd.read_csv(os.path.join(virb_dir, "roughness_metric.csv"), index_col=0)

  count = 0

  images = os.listdir(folder_dir)
  for image in images:
    count += 1
    if count % 100 == 0:
      print(count)
   
    if is_valid(image, rec_df, rough_df):
     image_list.append(image)
    else:
      print("Folder:", folder)
  
  valid_images['images'] = image_list
  return valid_images

# %%
valid_images()
# Out:
# Creating list of valid images in folder 2020-09-24-1
# Image 969902285s230ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902286s231ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902287s232ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902288s233ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# 100
# 200
# Image 969902506s251ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902507s252ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902508s253ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902509s254ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# 300
# Image 969902543s254ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902544s255ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902545s256ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902546s257ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# 400
# 500
# Image 969902765s243ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902766s244ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902767s245ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902768s246ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# 600
# Image 969902855s233ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902856s234ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902857s235ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969902858s236ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# 700
# Image 969903023s234ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903024s235ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903025s236ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903026s237ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# 800
# Image 969903039s250ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903040s251ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903041s252ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903042s253ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903054s231ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903055s232ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903056s233ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903057s234ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903098s242ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903099s243ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903100s244ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# Image 969903101s245ms.jpg does not have continuous readings.
# Folder: 2020-09-24-1
# 900
# 1000
# Image 969901730s242ms.jpg is not in range.
# Folder: 2020-09-24-1
# Image 969901731s243ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901732s244ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901733s245ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901734s246ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901735s247ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901736s248ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901737s249ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901738s250ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901739s251ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901740s252ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901741s253ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901742s254ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901743s255ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901744s256ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901745s257ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901746s258ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901747s226ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901748s227ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901749s228ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901750s229ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901751s230ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901752s231ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901753s232ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901754s233ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901755s234ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901756s235ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# Image 969901757s236ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-1
# 1100
# 1200
# 1300
# 1400
# 1500
# Creating list of valid images in folder 2020-09-24-2
# Image 969903325s689ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# Image 969903326s690ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# Image 969903327s691ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# Image 969903328s692ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# 100
# Image 969903403s700ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# Image 969903404s701ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# Image 969903405s702ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# Image 969903406s703ms.jpg does not have continuous readings.
# Folder: 2020-09-24-2
# 200
# Image 969903474s704ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903475s705ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903476s706ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903477s707ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903491s688ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903492s689ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903493s690ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903494s691ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903495s692ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903496s693ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903497s694ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903498s695ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903499s696ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903500s697ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903501s698ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903502s699ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903517s681ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903518s682ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Image 969903519s683ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-2
# Creating list of valid images in folder 2020-10-02-10-17-05-3
# Image 970588070s257ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588071s258ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588072s259ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588073s260ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588074s261ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588075s262ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588076s263ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588077s264ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588078s265ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588079s266ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588080s267ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588081s268ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588082s269ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588083s270ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# 100
# Image 970588249s269ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588250s270ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588251s271ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588252s272ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# 200
# 300
# Image 970588437s257ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588438s258ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588439s259ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588440s260ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# 400
# Image 970588494s247ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588495s248ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588496s249ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588497s250ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588498s251ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588499s252ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588500s253ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588501s254ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588502s255ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588503s256ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588504s257ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588505s258ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588506s259ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588507s260ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588508s261ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588509s262ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588510s263ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588511s264ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# Image 970588512s265ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-3
# 500
# Image 970588615s268ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588616s269ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588617s270ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588618s271ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-3
# Image 970588632s252ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-3
# Image 970588633s253ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-3
# Image 970588634s254ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-3
# Creating list of valid images in folder 2020-10-02-10-17-05-2
# Image 970587845s485ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-2
# Image 970587846s486ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-2
# Image 970587847s487ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-2
# Image 970587848s488ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-2
# 100
# Image 970587949s489ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587950s490ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587951s491ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587952s492ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587953s493ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587954s494ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587956s496ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# 200
# Image 970587957s497ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587958s498ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587959s499ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587960s500ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587961s501ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587962s502ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587963s503ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587964s504ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587965s505ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-2
# Image 970587966s506ms.jpg had validation errors in rec_df_window.
# Folder: 2020-10-02-10-17-05-2
# Image 970587967s507ms.jpg had validation errors in rec_df_window.
# Folder: 2020-10-02-10-17-05-2
# Creating list of valid images in folder 2020-09-23-VIRB0001
# Image 969829854s741ms.jpg is not in range.
# Folder: 2020-09-23-VIRB0001
# Image 969829933s753ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0001
# Image 969829934s754ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0001
# Image 969829935s755ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0001
# Creating list of valid images in folder 2020-09-23-VIRB0002
# Image 969829956s258ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0002
# Image 969829957s259ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0002
# Image 969829958s260ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0002
# Image 969829959s261ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0002
# Image 969829960s262ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0002
# Image 969829961s263ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0002
# Image 969829962s264ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0002
# Image 969829986s255ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969829987s256ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969829988s257ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969829989s258ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830003s272ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830004s273ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830005s274ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830006s275ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830044s246ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830045s247ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830046s248ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830047s249ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# 100
# Image 969830064s266ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830065s267ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Image 969830066s268ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0002
# Creating list of valid images in folder 2020-09-23-VIRB0004
# Image 969830811s205ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830812s206ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830813s207ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830814s208ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830830s191ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0004
# Image 969830831s192ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0004
# Image 969830832s193ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0004
# Image 969830833s194ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0004
# Image 969830856s217ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0004
# Image 969830857s218ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830858s219ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830859s220ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830860s221ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830861s222ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830862s189ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Image 969830863s190ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0004
# Creating list of valid images in folder 2020-09-23-VIRB0008
# Image 969832325s654ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0008
# Image 969832326s655ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0008
# Image 969832327s656ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0008
# Image 969832328s657ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0008
# Image 969832329s658ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0008
# Image 969832330s659ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0008
# Image 969832331s660ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-23-VIRB0008
# Image 969832335s664ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832336s665ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832337s666ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832338s667ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832360s656ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832361s657ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832362s658ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832363s659ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832417s646ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832418s647ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Image 969832419s648ms.jpg does not have continuous readings.
# Folder: 2020-09-23-VIRB0008
# Creating list of valid images in folder 2020-09-29-09-46-42-4
# Image 970329759s186ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-4
# Image 970329760s187ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-4
# 100
# 200
# Image 970329990s183ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-4
# Image 970329991s184ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-4
# Image 970329992s185ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-4
# Image 970329993s186ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-4
# 300
# 400
# 500
# Image 970330262s188ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330263s190ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330264s191ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330265s191ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330266s193ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330267s193ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330268s195ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330269s196ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330270s197ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330271s197ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330272s199ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330273s200ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330274s200ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330275s201ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330276s203ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330277s170ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330278s171ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330279s172ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330280s173ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330281s174ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330282s175ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330283s176ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330284s177ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330285s178ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330286s179ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330287s180ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330288s181ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330289s182ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330290s183ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330291s184ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330292s185ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330293s186ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330294s187ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330295s188ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330296s189ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330297s190ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330298s191ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330299s192ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# Image 970330300s193ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-4
# 600
# 700
# Image 970330468s194ms.jpg is not in range.
# Folder: 2020-09-29-09-46-42-4
# Image 970330469s195ms.jpg is not in range.
# Folder: 2020-09-29-09-46-42-4
# Image 970330470s196ms.jpg is not in range.
# Folder: 2020-09-29-09-46-42-4
# Image 970330471s197ms.jpg is not in range.
# Folder: 2020-09-29-09-46-42-4
# Creating list of valid images in folder 2020-09-24-3
# 100
# Image 969905363s178ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905364s179ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905365s180ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905366s181ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905367s182ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905372s187ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905373s188ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905374s189ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905375s190ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905376s191ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905377s192ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905378s193ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905379s194ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905380s195ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905381s196ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905382s164ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905383s165ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905384s166ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905385s167ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905386s168ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905387s169ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905388s170ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969905389s171ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# 200
# Image 969905455s170ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905456s171ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905457s172ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905458s173ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# 300
# Image 969905581s196ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905582s163ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905583s164ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905584s165ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# 400
# 500
# Image 969905802s183ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905803s184ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905804s185ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905805s186ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# 600
# Image 969905891s172ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905892s173ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905893s174ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905894s175ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# 700
# Image 969905977s191ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905978s192ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905979s193ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969905980s194ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# 800
# Image 969906091s172ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969906092s173ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969906093s174ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969906094s175ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969906095s176ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969906096s177ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969906097s178ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# 900
# Image 969906164s178ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969906165s179ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969906166s180ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969906167s181ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# 1000
# Image 969904825s174ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969904826s175ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969904827s176ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969904828s177ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# Image 969904829s178ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-24-3
# 1100
# 1200
# Image 969904973s188ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969904974s189ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969904975s190ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# Image 969904976s191ms.jpg does not have continuous readings.
# Folder: 2020-09-24-3
# 1300
# Image 969905077s192ms.jpg had validation errors in rec_df_window.
# Folder: 2020-09-24-3
# Image 969905078s193ms.jpg had validation errors in rec_df_window.
# Folder: 2020-09-24-3
# Image 969905079s194ms.jpg had validation errors in rec_df_window.
# Folder: 2020-09-24-3
# Image 969905080s195ms.jpg had validation errors in rec_df_window.
# Folder: 2020-09-24-3
# 1400
# 1500
# Creating list of valid images in folder 2020-09-24-4
# 100
# 200
# 300
# Image 969906584s651ms.jpg is not in range.
# Folder: 2020-09-24-4
# Image 969906585s652ms.jpg is not in range.
# Folder: 2020-09-24-4
# Image 969906586s653ms.jpg is not in range.
# Folder: 2020-09-24-4
# Creating list of valid images in folder 2020-07-28-06-01-11
# Image 964869061s713ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869062s714ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869063s715ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869064s716ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869078s697ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869079s698ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869080s699ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869081s700ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 100
# Image 964869179s698ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869180s699ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869181s700ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869182s701ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869183s702ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869184s703ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869185s704ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869189s708ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869190s709ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869191s710ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869192s711ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869193s712ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869194s713ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# 200
# Image 964869233s718ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869234s719ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869235s720ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869236s721ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869297s716ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869298s717ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869299s718ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869300s719ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 300
# Image 964869333s718ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869334s719ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869335s720ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869336s721ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869356s708ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869357s709ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869358s710ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869359s711ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869360s712ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869361s713ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869362s714ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869363s715ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869364s716ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869365s717ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869366s718ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869367s719ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# 400
# Image 964869432s717ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869433s718ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869434s719ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869435s720ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869436s721ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869437s722ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869438s723ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869439s724ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869440s725ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869441s726ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869468s720ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869469s721ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869470s722ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869471s723ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 500
# Image 964869544s729ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869545s697ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869546s698ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869564s716ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869565s717ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869566s718ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869567s719ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869568s720ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869569s721ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869570s722ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869571s723ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869572s724ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869573s725ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869574s726ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869575s727ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869576s728ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869577s729ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869578s730ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869579s697ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869580s698ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964869625s710ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869626s711ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 600
# Image 964869627s712ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869628s713ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869638s723ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869639s724ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869640s725ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869641s726ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869647s699ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869648s700ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869649s701ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869650s702ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869725s710ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869726s711ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 700
# Image 964869727s712ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869728s713ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 800
# Image 964869876s727ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869877s728ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869878s729ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869879s697ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869908s726ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869909s727ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869910s728ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869911s729ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869917s702ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869918s703ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869919s704ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964869920s705ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 900
# Image 964870024s708ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964870025s709ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964870026s710ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 1000
# Image 964870027s711ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868527s713ms.jpg is not in range.
# Folder: 2020-07-28-06-01-11
# Image 964868528s714ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964868529s715ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964868530s716ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964868531s717ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964868532s718ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# Image 964868533s719ms.jpg has one or more speed readings = 0.
# Folder: 2020-07-28-06-01-11
# 1100
# 1200
# Image 964868768s720ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868769s721ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868770s722ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868771s723ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868784s703ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868785s704ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868786s705ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868787s706ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 1300
# 1400
# Image 964868960s712ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868961s713ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868962s714ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868963s715ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868970s722ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868971s723ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868972s724ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# Image 964868973s725ms.jpg does not have continuous readings.
# Folder: 2020-07-28-06-01-11
# 1500
# Creating list of valid images in folder 2020-09-29-09-46-42-1
# Image 970325764s804ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325765s804ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325766s806ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325767s807ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# 100
# Image 970325950s789ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325951s790ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325952s791ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325953s792ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# 200
# Image 970325967s806ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325968s807ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325969s808ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970325970s809ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# 300
# 400
# Image 970326172s811ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326173s812ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326174s813ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326175s781ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# 500
# Image 970326286s792ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326287s793ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326288s794ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326289s795ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# 600
# 700
# Image 970326469s808ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326470s809ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326471s810ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326472s811ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-1
# Image 970326532s804ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326533s805ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326534s806ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326535s807ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326546s785ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326547s786ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326548s787ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326549s788ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326550s789ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326551s790ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326552s791ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326553s792ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# 800
# Image 970326563s802ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326564s803ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326565s804ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326566s805ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326567s806ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326568s807ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326569s808ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326570s809ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326571s810ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326572s811ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326573s812ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326592s797ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326593s798ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326594s799ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326595s800ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326609s781ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326610s782ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326611s783ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326612s784ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326613s785ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326614s786ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326615s787ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326616s788ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326617s789ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-1
# Image 970326618s790ms.jpg has one or more speed readings = 0.
# ...
# Folder: 2020-09-29-09-46-42-2
# Image 970328111s200ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328112s201ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328113s202ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328114s203ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328115s204ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328116s205ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328117s206ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328118s207ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328119s208ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328120s209ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328121s210ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328122s211ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328123s212ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328124s213ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328125s214ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328126s215ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328127s216ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328128s217ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328129s218ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970328130s219ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# 900
# 1000
# Image 970326820s210ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970326821s211ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970326822s212ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970326823s213ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970326824s214ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-2
# Image 970326849s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970326850s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970326851s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970326852s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 1100
# 1200
# Image 970326990s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970326991s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970326992s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970326993s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 1300
# Image 970327114s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327115s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327116s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327117s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 1400
# 1500
# Creating list of valid images in folder 2020-10-02-10-17-05-1
# 100
# Image 970586900s104ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586901s105ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586902s106ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586903s107ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# 200
# Image 970587012s83ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587013s84ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587014s85ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587015s86ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587028s99ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587029s100ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587030s101ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587031s102ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# 300
# Image 970587075s112ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587076s80ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587077s81ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587132s102ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587133s103ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587134s104ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587135s105ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587141s111ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587142s112ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587143s80ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587144s81ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# 400
# 500
# Image 970587266s103ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587267s104ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587268s105ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587269s106ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587308s112ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587309s113ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587310s80ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587328s98ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587329s99ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587330s100ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587331s101ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587354s91ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587355s92ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587356s93ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587357s94ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# 600
# Image 970587393s97ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587394s98ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587395s99ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587406s110ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587407s111ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587408s112ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587409s113ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587429s99ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587430s100ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587431s101ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587432s102ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# 700
# 800
# Image 970587605s108ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587606s109ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587607s110ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970587608s111ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# 900
# 1000
# Image 970586258s96ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586259s97ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586260s98ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586261s99ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586262s100ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586263s101ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586264s102ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586265s103ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586266s104ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586267s105ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586268s106ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586269s107ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586270s108ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586271s109ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586276s81ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586277s82ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586278s83ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# Image 970586279s84ms.jpg has one or more speed readings = 0.
# Folder: 2020-10-02-10-17-05-1
# 1100
# 1200
# 1300
# 1400
# Image 970586675s113ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586676s80ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586677s81ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586678s82ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586711s82ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586712s83ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586713s84ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# Image 970586714s85ms.jpg does not have continuous readings.
# Folder: 2020-10-02-10-17-05-1
# 1500
# Creating list of valid images in folder 2020-09-29-09-46-42-3
# Image 970328773s715ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328774s716ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328775s718ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328776s685ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328834s710ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328835s711ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328836s712ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328837s713ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 100
# Image 970328906s715ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328907s716ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328908s717ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328909s685ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 200
# 300
# Image 970329067s709ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329068s710ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329069s711ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329070s712ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329071s713ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329072s714ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329073s715ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329124s699ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329125s700ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329126s701ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329127s702ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329146s688ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329147s689ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329148s690ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329149s691ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 400
# Image 970329226s701ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329227s702ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329228s703ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329229s704ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 500
# Image 970329271s713ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329272s714ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329273s715ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329274s716ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# 600
# Image 970329364s706ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329365s707ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329366s708ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329367s709ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 700
# Image 970329471s713ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329472s714ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329473s715ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329474s716ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329483s691ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329484s692ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329485s693ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329486s694ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329528s703ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329529s704ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329530s705ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329531s706ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 800
# 900
# 1000
# Image 970329758s699ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328261s704ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328262s705ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328263s706ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328264s707ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 1100
# 1200
# 1300
# 1400
# 1500
