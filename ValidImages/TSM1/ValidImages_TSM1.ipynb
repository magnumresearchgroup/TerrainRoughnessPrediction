# %% [markdown]
# # Valid Images
# Create a DataFrame for each session with the valid images.
#
# **Validation:**
# 1. The image name must be in the format `[0-9]*s[0-9]*ms`.
#
# 2. `withinRange` to confirms that the  (`image_s` - 1 is after `rec_df`, `rough_df`, and `gps_df` begin and before `rec_df`, `rough_df`, and `gps_df` end.
#
# 3. Create `rec_df_window` which has the time window in `record.csv` used in calculating the timestamp corresponding to 5 meters ahead of the image and the time window used in calculating the roughness metric at this target timestamp. This checks for four additional withinRange validation errors:
#   - There must be a reading at the same `utc_s (s)` as the image.
#   - `target_dist` must be <= the last distance reading in `rec_df`.
#   - We must have readings in the time window used for the roughness calculation.
#   - The timestamp corresponding to the index of `target_dist` should be in `rough_df`.
#
# 4. `nonzero` iterates through `rec_df_window` to make sure that all speeds are nonzero in this time window.
#
# 5. We then create `rough_df_window` and `gps_df_window`, corresponding to the same time window as `rec_df_window` but for `roughness_metric.csv` and `gps.csv`. `continuous` then iterates through `rec_df_window`, `gps_df_window`, and `rough_df_window` to make sure that the timestamp readings are continuous as follows:
#   - Readings in `rec_df_window` should be no more than 1 second apart.
#   - Readings in `rough_df_window` should be no more than 50 ms apart (most readings are ~ 10 ms apart). **Note:** Consider changing the tolerance to 100 ms.
#   - Readings in `gps_df_window` should be no more than 500 ms apart (most readings are ~ 100 ms apart).
#
# 6. `consistent_utc` iterates through `gps_df_window` to check if the `abs(utc_s (s) - utc_timestamp(s) <= 1`.

# %% [markdown]
# ## Set-up

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
from collections import namedtuple
import csv
import re

# %% [markdown]
# ## Helper functions

# %%
# Difference in ms between t1 and t2
# Negative if s1 is before s2, positive if s2 is before s1
def findDifferenceMs(s1, ms1, s2, ms2):
  if (s1 > s2):
    return (s1-s2-1)*1000 + (1000-ms2) + ms1
  elif (s1 < s2):
    return -((s2-s1-1)*1000 + (1000-ms1) + ms2)
  else:
    return ms1-ms2

# Parse s and ms from image name in format XsYms
def parse_times(name):
  lhs, rhs = name.split("s", 1)
  rhs, ignore = rhs.split("ms", 1);
  return int(lhs), int(rhs)

# %% [markdown]
# ## Criteria for a valid image

# %% [markdown]
# #### Helper functions

# %%
# Return an empty DataFrame if there was a validation issue, else return
# the window of rec_df corresponding to the values used in labeling the image.
def rec_df_window(s, ms, rec_df, rough_df, m_ahead, window):
  
  # Validation 1: Make sure that a reading exists in rec_df with 'utc_s (s)' == s.
  # This is used for the closest_and_before calculation in the lableing script.
  row1 = rec_df[rec_df['utc_s (s)'] == s]
  if len(row1) == 0:
    return pd.DataFrame()
  
  # index1 corresponds to the image.
  index1 = row1.index.values[0]

  # Overestimate of the distance window.
  distance_window = rec_df[rec_df['utc_s (s)'] >= s]
  distance_window = distance_window[1:]
  d0_estimate = distance_window['distance (m)'].iloc[0]

  # Validation 2: Make sure the target_dist is in rec_df.
  target_dist = d0_estimate + m_ahead
  if rec_df['distance (m)'].iloc[-1] < target_dist:
    return pd.DataFrame()

  # index2 corresponds to the target distance.
  index2 = -1
  for index, row in distance_window.iterrows():
    dist = row['distance (m)']
    if dist > d0_estimate + m_ahead:
      index2 = index
      break
  
  # Validation 3: The roughness reading is from 1 second around 5 meters ahead.
  # We need at least one reading after index2 to calculate the roughness metric.
  if index2 == len(rec_df) - 1:
    return pd.DataFrame()
  
  index2 += 1

  # Validation 4: The time corresponding to index2 should be in rough_df.
  # TODO: Should we also check if it is in gps.csv?
  if findDifferenceMs(rough_df['utc_s'].iloc[-1], rough_df['utc_ms'].iloc[-1], rec_df['utc_s (s)'].iloc[index2], rec_df['utc_ms (ms)'].iloc[index2]) < 0:
    return pd.DataFrame()
  
  return rec_df[index1:index2+1]

# %%
def df_window(rec_window, df, utc_s, utc_ms):
  t1_s = rec_window['utc_s (s)'].iloc[0]
  t1_ms = rec_window['utc_ms (ms)'].iloc[0]
  t2_s = rec_window['utc_s (s)'].iloc[-1]
  t2_ms = rec_window['utc_ms (ms)'].iloc[-1]

  # If we have an entry before t1_s in bounds, start the search there.
  start_entry = df[df[utc_s] == t1_s - 1]
  if len(start_entry) == 0:
    start_index = 0
  else:
    start_index = start_entry.index.values[0]

  # Find index1 = closest to and before t1
  index1 = start_index
  while index1 < len(df) and (df.at[index1, utc_s] < t1_s or (df.at[index1, utc_s] == t1_s and df.at[index1, utc_ms] < t1_ms)):
    index1 += 1
  
  # index1 is set to the entry right after the t1_s, set it to the first entry before t1_s
  if index1 > 0:
    index1 -= 1
  
  # Find index2 = closest to and after t2
  index2 = index1
  while index2 < len(df) and (df.at[index2, utc_s] < t2_s or (df.at[index2, utc_s] == t2_s and df.at[index2, utc_ms] < t2_ms)):
    index2 += 1
  
  # TODO: if index1 = index2, should we declare the image invalid?
  return df[index1:index2+1]

# %% [markdown]
# #### Validity checks

# %%
# (df_s1, df_ms1) is the start time of df, (df_s2, df_ms2) is the end time of df
def withinRange(s, ms, window, df_s1, df_ms1, df_s2, df_ms2):
  if findDifferenceMs(s - 1, 0, df_s1, df_ms1) < 0:
    return False
  
  if findDifferenceMs(df_s2, df_ms2, s, ms) < 0:
    return False

  return True

# %%
def nonzero(rec_window):
  for _, row in rec_window.iterrows():
    if row['enhanced_speed (m/s)'] == 0:
      return False
  
  return True

# %%
def continuous(df, tolerance, utc_s, utc_ms):
  for i in range(len(df)):
    if i == 0:
      continue
      
    if findDifferenceMs(df[utc_s].iloc[i], df[utc_ms].iloc[i], df[utc_s].iloc[i-1], df[utc_ms].iloc[i-1]) > tolerance:
      return False
  
  return True

# %%
def consistent_utc(gps_window):
  for _, row in gps_window.iterrows():
    if not abs(row['utc_s (s)'] - row['utc_timestamp (s)'] <= 1):
      print(row)
      return False
      
  return True

# %%
def is_valid(image, rec_df, rough_df, gps_df, window, m_ahead):
  s, ms = parse_times(image)

  # Criteria 1: Image name is in format XsYms
  if not bool(re.match("[0-9]*s[0-9]*ms", image)):
    print("Image", image, "has an improper name format.")
    return False
  
  # Criteria 2: Image time - int(1 + (window / 1000.)) should be after df_s, df_ms
  in_range_rec = withinRange(s, ms, window, rec_df['utc_s (s)'].iloc[0], rec_df['utc_ms (ms)'].iloc[0], rec_df['utc_s (s)'].iloc[-1], rec_df['utc_ms (ms)'].iloc[-1])
  in_range_rough = withinRange(s, ms, window, rough_df['utc_s'].iloc[0], rough_df['utc_ms'].iloc[0], rough_df['utc_s'].iloc[-1], rough_df['utc_ms'].iloc[-1])
  in_range_gps = withinRange(s, ms, window, gps_df['utc_s (s)'].iloc[0], gps_df['utc_ms (ms)'].iloc[0], gps_df['utc_s (s)'].iloc[-1], gps_df['utc_ms (ms)'].iloc[-1])
  if not in_range_rec or not in_range_rough or not in_range_gps:
    print("Image", image, "is not in range.")
    return False

  # Criteria 3: Additional range checks during creation of rec_window
  # If one of these check fails, rec_window = pd.DataFrame()
  rec_window = rec_df_window(s, ms, rec_df, rough_df, m_ahead, window)
  if len(rec_window) == 0:
    print("Image", image, "had validation errors in rec_df_window.")
    return False
  
  # Criteria 4: The speeds in the window surrounding the image must be nonzero
  if not nonzero(rec_window):
    print("Image", image, "has one or more speed readings = 0.")
    return False
  
  # Criteria 5: Timestamps in record.csv, roughness_metric.csv, and gps.csv are continuous
  rough_window = df_window(rec_window, rough_df, 'utc_s', 'utc_ms')
  gps_window = df_window(rec_window, gps_df, 'utc_s (s)', 'utc_ms (ms)')
  
  continuous_rec = continuous(rec_window, 1001, 'utc_s (s)', 'utc_ms (ms)')
  continuous_rough = continuous(rough_window, 50, 'utc_s', 'utc_ms')
  continuous_gps = continuous(gps_window, 500, 'utc_s (s)', 'utc_ms (ms)')
  
  if not (continuous_rec and continuous_rough and continuous_gps):    
    print("Image", image, "does not have continuous readings.")
    return False

  # Criteria 6: Calculated UTC timestamp matches the recorded UTC timestamp
  consistent_utc_time = consistent_utc(gps_window)
  if not consistent_utc_time:
    print("Image", image, "does not have consistent UTC time.")
    return False

  return True

# %% [markdown]
# ## Test data

# %%
# test_rec_df = pd.read_csv('/gdrive/My Drive/Labeling/SensorData/Garmin/2020-09-29-09-46-42-garmin/record.csv', index_col=0)
# test_rec_df = test_rec_df.filter(items=['utc_s (s)', 'utc_ms (ms)', 'distance (m)', 'enhanced_speed (m/s)'])
# test_rough_df = pd.read_csv('/gdrive/My Drive/Labeling/SensorData/Virb/2020-09-29-09-46-42/roughness_metric.csv', index_col=0)
# test_gps_df = pd.read_csv('/gdrive/My Drive/Labeling/SensorData/Virb/2020-09-29-09-46-42/gps.csv', index_col=0)
# test_gps_df = test_gps_df.filter(items=['utc_s (s)', 'utc_ms (ms)', 'utc_timestamp (s)'])

# window = 500
# m_ahead = 5

# # Test nonzero
# Range with 0 values: 2771 - 2820, 970328033 - 970328081
# Range with no 0 values: 100 - 120, 970325361 - 970325380, however not in range with gps.csv
# Range where second part has 0 values: 2746 - 2747, 970328008 - 970328009 
# Range where first part has 0 values: 2868 - 2869, 970328130 - 970328131
# print(is_valid("970328034s0ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))
# print(is_valid("970325361s50ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))
# print(is_valid("970328008s50ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))
# print(is_valid("970328130s50ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))

# # Test withinRange
# # Start time of test_rec_df = (970325257, 0)
# # Start time of test_rough_df = (970325257, 571)
# # Start time of test_gps_df = (970325478, 800.0)
# print(is_valid("970325257s0ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))
# print(is_valid("970325258s0ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))
# print(is_valid("970325258s571ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))
# print(is_valid("970325500s0ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))

# Test consistent_utc
# print(is_valid("970327043s0ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))
# print(is_valid("970329000s0ms", test_rec_df, test_rough_df, test_gps_df, window, m_ahead))

# %% [markdown]
# ## Create DataFrame with valid images

# %%
CSVDirs = namedtuple('CSVDirs', ['virb_dir', 'garmin_dir'])

def csv_path(folder):
  root_csv_dir = '/gdrive/My Drive/Labeling/SensorData'
  virb_dir = os.path.join(root_csv_dir, 'Virb', folder)
  garmin_dir = os.path.join(root_csv_dir, 'Garmin', folder + '-garmin')
  return CSVDirs(virb_dir, garmin_dir)

video_csvs = {
    "2020-07-28-06-01-11": csv_path('2020-07-28-06-01-11'),
    "2020-09-23-VIRB0001": csv_path('2020-09-23-16-10-10'),
    "2020-09-23-VIRB0002": csv_path('2020-09-23-16-10-10'),
    "2020-09-23-VIRB0004": csv_path('2020-09-23-16-10-10'),
    "2020-09-23-VIRB0008": csv_path('2020-09-23-16-10-10'),
    "2020-09-24-1": csv_path('2020-09-24-12-07-41'),
    "2020-09-24-2": csv_path('2020-09-24-12-07-41'),
    "2020-09-24-3": csv_path('2020-09-24-12-07-41'),
    "2020-09-24-4": csv_path('2020-09-24-12-07-41'),
    "2020-09-29-09-46-42-1": csv_path('2020-09-29-09-46-42'),
    "2020-09-29-09-46-42-2": csv_path('2020-09-29-09-46-42'),
    "2020-09-29-09-46-42-3": csv_path('2020-09-29-09-46-42'),
    "2020-09-29-09-46-42-4": csv_path('2020-09-29-09-46-42'),
    "2020-10-02-10-17-05-1": csv_path('2020-10-02-10-17-05'),
    "2020-10-02-10-17-05-2": csv_path('2020-10-02-10-17-05'),
    "2020-10-02-10-17-05-3": csv_path('2020-10-02-10-17-05'),
}

# %%
# Label all images in Labeling/VideoData/RealVideoSplit/VideoFrames
def valid_images():
  window = 500
  m_ahead = 5

  with open('/gdrive/My Drive/Labeling/ValidImages/valid_images.txt', 'w') as outfile:
    
    frame_directory = '/gdrive/My Drive/Labeling/VideoData/RealVideoSplit/VideoFrames'
    for root, dirs, files in os.walk(frame_directory):
      if root == '/gdrive/My Drive/Labeling/VideoData/RealVideoSplit/VideoFrames':
        for dir in dirs:
          if dir in video_csvs:
            virb_dir = video_csvs[dir].virb_dir
            garmin_dir = video_csvs[dir].garmin_dir
            df = valid_images_in_folder(os.path.join(root, dir), virb_dir, garmin_dir, window, m_ahead)
            output = dir + "\nNumber of valid images: " + str(len(df)) + " Total images: " + str(len(os.listdir(os.path.join(root,dir)))) + "\n"
            outfile.write(output)

            csv_name = dir + '.csv'
            df.to_csv(os.path.join('/gdrive/My Drive/Labeling/ValidImages/', csv_name), index=False)

# %%
# Return lists with the video name, image name, and roughness group for all 
# images in the folder
def valid_images_in_folder(folder_dir, virb_dir, garmin_dir, window, m_ahead):
  folder = os.path.split(folder_dir)[1]
  print("Creating list of valid images in folder", folder)

  valid_images = pd.DataFrame()
  image_list = []

  rec_df = pd.read_csv(os.path.join(garmin_dir, "record.csv"), index_col=0)
  rec_df = rec_df.filter(items=['utc_s (s)', 'utc_ms (ms)', 'distance (m)', 'enhanced_speed (m/s)'])
  rough_df = pd.read_csv(os.path.join(virb_dir, "roughness_metric.csv"), index_col=0)
  gps_df = pd.read_csv(os.path.join(virb_dir, "gps.csv"), index_col=0)
  gps_df = gps_df.filter(items=['utc_s (s)', 'utc_ms (ms)', 'utc_timestamp (s)'])

  count = 0

  images = os.listdir(folder_dir)
  for image in images:
    count += 1
    if count % 100 == 0:
      print(count)
   
    if is_valid(image, rec_df, rough_df, gps_df, window, m_ahead):
     image_list.append(image)
    else:
      print("Folder:", folder)
  
  valid_images['images'] = image_list
  return valid_images

# %%
valid_images()
# Out:
# Streaming output truncated to the last 5000 lines.
# Image 970327469s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327470s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327471s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327472s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327473s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327474s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327475s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327476s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327477s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327478s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327479s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327480s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327481s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327482s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327483s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327484s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327485s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327486s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327487s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327489s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327488s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327490s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327491s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327492s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327493s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327494s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327495s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327496s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327497s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327498s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327499s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327500s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327501s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327502s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327503s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327504s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327505s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327506s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327507s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327508s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327509s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327510s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327511s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327512s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327513s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327514s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327515s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327516s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327517s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327518s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327519s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327520s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327521s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327522s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327523s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327524s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327525s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327526s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327527s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327528s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327529s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327530s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327531s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327532s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327533s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327534s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327535s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327536s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327537s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327538s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327539s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327540s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327541s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327542s232ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327543s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327544s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327545s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327546s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327547s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327548s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327549s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327550s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327551s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327552s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327553s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327554s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327555s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327556s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327557s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 300
# Image 970327558s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327559s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327560s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327561s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327562s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327563s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327564s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327565s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327566s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327567s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327568s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327569s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327570s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327571s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327572s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327573s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327574s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327575s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327576s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327577s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327578s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327579s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327580s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327581s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327582s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327583s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327584s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327585s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327586s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327587s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327588s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327589s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327590s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327591s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327592s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327593s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327594s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327595s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327596s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327597s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327598s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327599s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327600s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327601s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327602s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327603s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327604s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327605s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327606s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327607s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327608s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327609s198ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327610s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327611s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327612s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327613s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327614s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327615s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327616s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327617s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327618s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327619s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327620s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327621s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327622s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327623s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327624s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327625s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327626s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327627s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327628s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327629s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327630s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327631s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327632s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327633s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327634s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327635s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327636s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327637s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327638s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327639s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327640s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327641s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327642s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327643s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327644s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327645s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327646s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327647s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327648s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327649s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327650s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327651s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327652s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327653s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327654s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327655s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327656s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327657s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 400
# Image 970327658s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327659s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327660s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327661s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327662s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327663s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327664s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327665s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327666s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327667s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327668s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327669s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327670s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327671s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327672s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327673s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327674s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327675s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327676s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327677s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327678s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327679s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327680s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327681s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327682s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327683s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327684s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327686s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327685s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327687s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327688s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327689s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327690s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327691s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327692s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327693s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327694s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327695s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327696s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327697s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327698s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327699s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327700s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327701s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327702s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327703s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327704s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327705s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327706s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327707s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327708s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327709s198ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327710s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327711s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327712s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327713s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327714s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327715s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327716s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327717s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327718s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327719s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327720s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327721s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327722s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327723s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327724s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327725s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327726s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327727s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327728s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327729s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327730s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327731s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327732s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327733s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327734s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327735s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327736s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327737s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327738s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327739s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327740s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327741s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327742s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327743s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327744s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327745s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327746s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327747s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327748s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327749s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327750s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327751s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327752s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327753s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327754s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327755s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327756s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327757s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 500
# Image 970327758s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327759s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327760s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327761s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327762s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327763s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327764s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327765s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327766s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327767s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327768s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327769s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327770s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327771s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327772s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327773s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327774s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327775s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327776s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327777s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327778s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327779s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327780s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327781s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327782s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327783s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327784s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327785s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327786s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327787s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327788s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327789s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327790s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327791s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327792s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327793s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327794s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327795s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327796s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327797s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327798s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327799s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327800s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327801s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327802s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327803s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327804s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327805s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327806s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327807s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327808s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327809s232ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327810s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327811s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327812s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327813s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327814s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327815s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327816s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327817s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327818s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327819s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327820s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327821s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327822s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327823s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327824s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327825s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327826s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327827s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327828s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327829s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327830s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327831s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327832s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327833s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327834s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327835s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327836s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327837s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327838s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327839s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327840s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327841s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327842s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327843s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327844s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327845s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327846s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327847s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327848s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327849s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327850s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327851s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327852s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327853s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327854s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327855s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327856s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327857s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 600
# Image 970327858s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327859s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327860s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327861s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327862s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327863s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327864s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327865s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327866s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327867s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327868s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327869s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327870s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327871s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327872s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327873s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327874s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327875s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327876s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327877s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327878s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327879s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327880s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327881s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327882s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327883s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327884s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327885s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327886s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327887s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327888s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327889s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327890s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327891s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327892s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327893s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327894s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327895s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327896s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327897s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327898s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327899s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327900s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327901s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327902s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327903s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327904s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327905s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327906s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327907s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327908s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327909s232ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327910s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327911s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327912s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327913s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327914s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327915s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327916s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327917s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327918s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327919s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327920s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327921s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327922s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327923s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327924s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327925s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327926s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327927s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327928s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327929s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327930s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327931s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327932s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327933s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327934s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327935s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327936s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327937s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327938s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327939s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327940s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327941s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327942s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327943s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327944s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327945s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327946s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327947s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327948s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327949s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327950s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327951s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327952s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327953s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327954s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327955s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327956s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327957s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# 700
# Image 970327958s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327959s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327960s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327961s217ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327962s218ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327963s219ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327964s220ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327965s221ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327966s222ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327967s223ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327968s224ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327969s225ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327970s226ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327971s227ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327972s228ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327973s229ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327974s230ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327975s231ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327976s198ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327977s199ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327978s200ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327979s201ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327980s202ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327981s203ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327982s204ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327983s205ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327984s206ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327985s207ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327986s208ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327987s209ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327988s210ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327989s211ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327990s212ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327991s213ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327992s214ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327993s215ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327994s216ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-2
# Image 970327995s217ms.jpg does not have continuous readings.
# ...
# Image 970586626s97ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586627s98ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586628s99ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586629s100ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586630s101ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586631s102ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586632s103ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586633s104ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586634s105ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586635s106ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586636s107ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586637s108ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586638s109ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586639s110ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586640s111ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586641s112ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586642s80ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586643s81ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586644s82ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586645s83ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586646s84ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586647s85ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586648s86ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586649s87ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586650s88ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586651s89ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586652s90ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586653s91ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586654s92ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586655s93ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586656s94ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# 1400
# Image 970586657s95ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586658s96ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586659s97ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586660s98ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586661s99ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586662s100ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586663s101ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586664s102ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586665s103ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586666s104ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586667s105ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586668s106ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586669s107ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586670s108ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586671s109ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586672s110ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586673s111ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586674s112ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586675s113ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586676s80ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586677s81ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586678s82ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586679s83ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586680s84ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586681s85ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586682s86ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586683s87ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586684s88ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586685s89ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586686s90ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586687s91ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586688s92ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586689s93ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586690s94ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586691s95ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586692s96ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586693s97ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586694s98ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586695s99ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586696s100ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586697s101ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586698s102ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586699s103ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586700s104ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586701s105ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586702s106ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586703s107ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586704s108ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586705s109ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586706s110ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586707s111ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586708s112ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586709s80ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586710s81ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586711s82ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586712s83ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586713s84ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586714s85ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586715s86ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586716s87ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586717s88ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586718s89ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586719s90ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586720s91ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586721s92ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586722s93ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586723s94ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586724s95ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586725s96ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586726s97ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586727s98ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586728s99ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586729s100ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586730s101ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586731s102ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586732s103ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586733s104ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586734s105ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586735s106ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586736s107ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586737s108ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586738s109ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586739s110ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586740s111ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586741s112ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586742s79ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586743s81ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586744s82ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586745s83ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586746s84ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586747s84ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586748s86ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586749s86ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586750s88ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586751s89ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586752s89ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586753s91ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586754s91ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586755s93ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586756s94ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# 1500
# Image 970586757s95ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Image 970586758s96ms.jpg is not in range.
# Folder: 2020-10-02-10-17-05-1
# Creating list of valid images in folder 2020-09-29-09-46-42-3
# Image 970328773s715ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328774s716ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328775s718ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328776s685ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328833s709ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328834s710ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328835s711ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328836s712ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328837s713ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 100
# Image 970328906s715ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328907s716ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328908s717ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328909s685ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 200
# Image 970328971s713ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328972s714ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328973s715ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328974s716ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328975s717ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 300
# Image 970329062s704ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329063s705ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329064s706ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329065s707ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329066s708ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329067s709ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329068s710ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329069s711ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329070s712ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329071s713ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329072s714ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329073s715ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329123s698ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329124s699ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329125s700ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329126s701ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329127s702ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329146s688ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329147s689ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329148s690ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329149s691ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 400
# Image 970329226s701ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329227s702ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329228s703ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329229s704ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 500
# Image 970329270s712ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329271s713ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329272s714ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329273s715ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# Image 970329274s716ms.jpg has one or more speed readings = 0.
# Folder: 2020-09-29-09-46-42-3
# 600
# Image 970329365s707ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329366s708ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329367s709ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 700
# Image 970329471s713ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329472s714ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329473s715ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329474s716ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329483s691ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329484s692ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329485s693ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329486s694ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329527s702ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329528s703ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329529s704ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329530s705ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970329531s706ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 800
# 900
# 1000
# Image 970329758s699ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328262s705ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328263s706ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# Image 970328264s707ms.jpg does not have continuous readings.
# Folder: 2020-09-29-09-46-42-3
# 1100
# 1200
# 1300
# 1400
# 1500
